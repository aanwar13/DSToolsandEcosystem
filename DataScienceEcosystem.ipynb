# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ### Introduction
# ### This notebook summarizes the Data Science tools and Ecosystem

# %% [markdown]
# ### Objectives:
# * List popular languages for Data Science
# * List commonly used libraries for Data Science
# * Tabulate commonly used Data Science Tools
# * Illustrate how to use code block for simple arithematic processing
# * Demonstrate how to add comments in code block

# %% [markdown]
# ### Some of the popular languages Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# ### Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. NumPy
# 3. ggplot

# %% [markdown]
#  | Data Science Tools|
#  :-----------------:
#
#   |Jupyter |
# :----------------:
#
#    | RStudio  |
#    :--------------:
#
#
#    |Apache Spark|
#    :------------:

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %%
# This code cell will convert 200 minutes to hours by divding with 60
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Asim Anwar
